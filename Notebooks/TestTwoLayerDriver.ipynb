# %%
using Revise

includet("../utils/IFMAB3.jl")
includet("../utils/SequencedOutputs.jl")
includet("../raytracing/GPURaytracing.jl")
includet("../swqg/TwoLayerQG.jl")
includet("../swqg/TwoLayerParameters.jl")

# %%
includet("../swqg/TwoLayerRaytracingDriver.jl")

# %%
start!()
# Out:
# Total steps: 4889240. Spin-up steps: 1629746, Output every 1620 steps. Total: 2012 output frames. Diagnostics every 81 steps, max writes per file: 3000
# Total time: 30000.000000, Time step: 0.006136, Estimated CFL: 0.050
# Packets: 16384. Output every 162 steps. Total 20120 packet frames
# Parameters
#   ├───── parameter: U -> Float32
#   ├───── parameter: μ -> Float32
#   ├───── parameter: ν -> Float32
#   ├───── parameter: nν -> Int64
#   ├───── parameter: F -> Float32
#   └───── parameter: rfftplan -> CUDA.CUFFT.rCuFFTPlan{Float32, -1, false, 3}
#
# step: 0000, t: 0.00, cfl: 1.75e-04, time: 0.03 mins
# step: 1620, t: 9.94, cfl: 1.45e-04, time: 0.11 mins
# step: 3240, t: 19.88, cfl: 1.40e-04, time: 0.12 mins
# step: 4860, t: 29.82, cfl: 1.46e-04, time: 0.13 mins
# step: 6480, t: 39.76, cfl: 1.50e-04, time: 0.15 mins
# step: 8100, t: 49.70, cfl: 1.51e-04, time: 0.16 mins
# step: 9720, t: 59.63, cfl: 1.50e-04, time: 0.17 mins
# step: 11340, t: 69.57, cfl: 1.47e-04, time: 0.18 mins
# ...

# %%
using CUDA
a = CuArray([1; 1; 1; 1; 1;;])
dropdims(a, dims=2)
# Out:
# 5-element CuArray{Int64, 1, CUDA.DeviceMemory}:
#  1
#  1
#  1
#  1
#  1
